# %%
from __future__ import print_function
import sys
choices = []

for x in range (0, 9) :
    choices.append(str(x + 1))

playerOneTurn = True
winner = False

def printBoard() :
    print( '\n -----')
    print( '|' + choices[0] + '|' + choices[1] + '|' + choices[2] + '|')
    print( ' -----')
    print( '|' + choices[3] + '|' + choices[4] + '|' + choices[5] + '|')
    print( ' -----')
    print( '|' + choices[6] + '|' + choices[7] + '|' + choices[8] + '|')
    print( ' -----\n')
count=0
while not winner :

    printBoard()
    
    if(count>=9):
        print("Draw")
        sys.exit()
    if playerOneTurn :
        print( "Player 1:")
    else :
        print( "Player 2:")

    try:
        choice = int(input(">> "))
    except:
        print("please enter a valid field")
        continue
    if(choice>9):
        print("entered a wrong choice")
        continue
    if choices[choice - 1] == 'X' or choices [choice-1] == 'O':
        print("illegal move, plase try again")
        continue

    if playerOneTurn :
        count+=1
        choices[choice - 1] = 'X'
    else :
        count+=1
        choices[choice - 1] = 'O'

    playerOneTurn = not playerOneTurn

    for x in range (0, 3) :
        y = x * 3
        if (choices[y] == choices[(y + 1)] and choices[y] == choices[(y + 2)]) :
            winner = True
            printBoard()
        if (choices[x] == choices[(x + 3)] and choices[x] == choices[(x + 6)]) :
            winner = True
            printBoard()

    if((choices[0] == choices[4] and choices[0] == choices[8]) or 
       (choices[2] == choices[4] and choices[4] == choices[6])) :
        winner = True
        printBoard()

print ("Player " + str(int(playerOneTurn + 1)) + " wins!\n")
# Out:
#  -----
# |1|2|3|
#  -----
# |4|5|6|
#  -----
# |7|8|9|
#  -----
#
# Player 1:
# >> 1
#
#  -----
# |X|2|3|
#  -----
# |4|5|6|
#  -----
# |7|8|9|
#  -----
#
# Player 2:
# >> 9
#
#  -----
# |X|2|3|
#  -----
# |4|5|6|
#  -----
# |7|8|O|
#  -----
#
# Player 1:
# >> 5
#
#  -----
# |X|2|3|
#  -----
# |4|X|6|
#  -----
# |7|8|O|
#  -----
#
# Player 2:
# >> 3
#
#  -----
# |X|2|O|
#  -----
# |4|X|6|
#  -----
# |7|8|O|
#  -----
#
# Player 1:
# >> 6
#
#  -----
# |X|2|O|
#  -----
# |4|X|X|
#  -----
# |7|8|O|
#  -----
#
# Player 2:
# >> 4
#
#  -----
# |X|2|O|
#  -----
# |O|X|X|
#  -----
# |7|8|O|
#  -----
#
# Player 1:
# >> 2
#
#  -----
# |X|X|O|
#  -----
# |O|X|X|
#  -----
# |7|8|O|
#  -----
#
# Player 2:
# >> 8
#
#  -----
# |X|X|O|
#  -----
# |O|X|X|
#  -----
# |7|O|O|
#  -----
#
# Player 1:
# >> 7
#
#  -----
# |X|X|O|
#  -----
# |O|X|X|
#  -----
# |X|O|O|
#  -----
#
# Draw
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\JIGYASHU\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
